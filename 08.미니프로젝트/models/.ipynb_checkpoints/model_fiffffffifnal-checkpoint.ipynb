# %%
# def fit_metrics_print(model, X_train, y_train, X_val, y_val):
#     from sklearn.metrics import accuracy_score, classification_report
#     model.fit(X_train, y_train)
    
#     pred_train = model.predict(X_train)
#     pred_val = model.predict(X_val)
#     print(model)
#     print()
#     print('train accuracy :', accuracy_score(y_train, pred_train))
#     print('validation accuracy :', accuracy_score(y_val, pred_val))
#     print('='*60)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

mpl.style.use('seaborn')

# %% [markdown]
# #### after

# %%
X_aft = pd.read_csv('../data/prepcd_lbe_train.csv')
X_aft.drop(columns='target', inplace=True)
y_aft = pd.read_csv('../data/prepcd_lbe_train.csv')['target']
X_test_aft = pd.read_csv('../data/prepcd_lbe_test.csv')

# %%
X_train_aft, X_val_aft, y_train_aft, y_val_aft = train_test_split(X_aft, y_aft, stratify=y_aft, shuffle=True, random_state=1)
X_train_aft.shape, X_val_aft.shape, y_train_aft.shape, y_val_aft.shape
# Out:
# ((14368, 13), (4790, 13), (14368,), (4790,))

# %% [markdown]
# #### before

# %%
X_bft = pd.read_csv('../data/prepcd_scaled_train.csv')
X_bft.drop(columns='target', inplace=True)
y_bft = pd.read_csv('../data/prepcd_scaled_train.csv')['target']
X_test_bft = pd.read_csv('../data/prepcd_scaled_test.csv')

# %%
X_train_bfr, X_val_bfr, y_train_bfr, y_val_bfr = train_test_split(X_bft, y_bft, stratify=y_bft, shuffle=True, random_state=1)
X_train_bfr.shape, X_val_bfr.shape, y_train_bfr.shape, y_val_bfr.shape
# Out:
# ((14368, 31), (4790, 31), (14368,), (4790,))

# %% [markdown]
# - - -
# # XGBoost_randomized

# %%
param = dict(
    n_estimators=[100, 200, 300, 400, 500],
    learning_rate=[0.001,0.005,0.01,0.05,0.1,0.5],
    max_depth=range(1, 7)
)

# %%
from xgboost import XGBClassifier

xgb_bfr = XGBClassifier(n_estimators=200,
                   learning_rate=0.5,
                   max_depth=2,
                   random_state=1)
xgb_bfr.fit(X_train_bfr, y_train_bfr)
# Out:
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [00:57:27] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.5, max_delta_step=0, max_depth=2,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=200, n_jobs=12, num_parallel_tree=1, random_state=1,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# #### nopoly-nooversampling

# %%
random_xgb_bfr = RandomizedSearchCV(xgb_bfr,
                             param_distributions=param,
                             n_iter=10,
                             scoring='accuracy',
                             cv=3,
                             n_jobs=-1,
                             random_state=1
                             )
random_xgb_bfr.fit(X_train_bfr, y_train_bfr)
# Out:
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\sklearn\model_selection\_search.py:921: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan]
#   category=UserWarning
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [00:57:44] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1, gamma=0,
#                                            gpu_id=-1, importance_type='gain',
#                                            interaction_constraints='',
#                                            learning_rate=0.5, max_delta_step=0,
#                                            max_depth=2, min_child_weight=1,
#                                            missing=nan,
#                                            monotone_constraints='()',
#                                            n_estimators=200, n_jobs=12,
#                                            num_parallel_tree=1, random_state=1,
#                                            reg_alpha=0, reg_lambda=1,
#                                            scale_pos_weight=1, subsample=1,
#                                            tree_method='exact',
#                                            validate_parameters=1,
#                                            verbosity=None),
#                    n_jobs=-1,
#                    param_distributions={'learning_rate': [0.001, 0.005, 0.01,
#                                                           0.05, 0.1, 0.5],
#                                         'max_depth': range(1, 7),
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500]},
#                    random_state=1, scoring='accuracy')

# %%
be_bfr = random_xgb_bfr.best_estimator_
pd.Series(be_bfr.feature_importances_, index=X_train.columns).sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------
# NameError                     Traceback (most recent call last)
# <ipython-input-10-0a1da476dd52> in <module>
# ----> 1 be = random_xgb.best_estimator_
#       2 pd.Series(be.feature_importances_, index=X_train.columns).sort_values(ascending=False)
#
# NameError: name 'random_xgb' is not defined

# %%
pd.DataFrame(random_xgb.cv_results_).sort_values('rank_test_score')

# %%
pred_train = random_xgb.predict(X_train)
pred_val = random_xgb.predict(X_val)

print('train accuracy :', accuracy_score(y_train, pred_train))
print('validation accuracy :', accuracy_score(y_val, pred_val))

# %% [markdown]
# ## ROC Curve vs. PR Curve (feat. 김성환 강사님)
# - ROC: 이진분류에서 양성클래스 탐지와 음성클래스 탐지의 중요도가 비슷할 때 사용(개고양이 분류)
# - PR curve(Precision Recall 커브): 양성 클래스 탐지가 음성클래스 탐지의 중요도보다 높을 경우 사용(암환자 진단)

# %%
# score_df = []
# score_df = get_scores(score_df, random_xgb, X_val, y_val, "random_xgb")
# score_df

# %%
y_pred_proba = random_xgb.predict_proba(X_val)[:,1]

# %%
from sklearn.metrics import roc_auc_score, f1_score, plot_confusion_matrix, \
    plot_roc_curve, plot_precision_recall_curve, classification_report, precision_score, recall_score

# %%
df_report = pd.DataFrame(columns={'ROC-AUC'}, data=[0])
df_report['ROC-AUC'] = roc_auc_score(y_val, y_pred_proba)
df_report['F1'] = f1_score(y_val, pred_val)
df_report['precision_0'] = precision_score(y_val, pred_val, pos_label=0)
df_report['recall_0'] = recall_score(y_val, pred_val, pos_label=0)
df_report['precision_1'] = precision_score(y_val, pred_val, pos_label=1)
df_report['recall_1'] = recall_score(y_val, pred_val, pos_label=1)

df_report.index = ['XGBClassifier']
df_report
# Out:
#                 ROC-AUC        F1  precision_0  recall_0  precision_1  \
# XGBClassifier  0.807359  0.583333     0.860132  0.868743     0.592401
#
#                recall_1
# XGBClassifier  0.574539

# %%
# ROC curve 그리는 코드
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))

plot_precision_recall_curve(random_xgb, X_val, y_val, ax=ax1)
plot_roc_curve(random_xgb, X_val, y_val, ax=ax2)
# Out:
# ----------------------------------------------------------------------
# ValueError                           Traceback (most recent call last)
# <ipython-input-264-1f2c4c6579ce> in <module>
#       2 fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 5))
#       3
# ----> 4 plot_precision_recall_curve(random_xgb, X_val, y_val, ax=ax1)
#       5 plot_roc_curve(random_xgb, X_val, y_val, ax=ax2)
#
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\sklearn\metrics\_plot\precision_recall_curve.py in plot_precision_recall_curve(estimator, X, y, sample_weight, response_method, name, ax, pos_label, **kwargs)
#     204
#     205     y_pred, pos_label = _get_response(
# --> 206         X, estimator, response_method, pos_label=pos_label)
#     207
#     208     precision, recall, _ = precision_recall_curve(y, y_pred,
#
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\sklearn\metrics\_plot\base.py in _get_response(X, estimator, response_method, pos_label)
#      89         estimator, response_method)
#      90
# ---> 91     y_pred = prediction_method(X)
#      92
#      93     if pos_label is not None and pos_label not in estimator.classes_:
#
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     118
#     119         # lambda, but not partial, allows help() to work with update_wrapper
# --> 120         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     121         # update the docstring of the returned function
#     122         update_wrapper(out, self.fn)
#
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\sklearn\model_selection\_search.py in predict_proba(self, X)
#     555         """
#     556         self._check_is_fitted('predict_proba')
# --> 557         return self.best_estimator_.predict_proba(X)
#     558
#     559     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\xgboost\sklearn.py in predict_proba(self, X, ntree_limit, validate_features, base_margin)
#    1015         """
#    1016         test_dmatrix = DMatrix(X, base_margin=base_margin,
# -> 1017                                missing=self.missing, nthread=self.n_jobs)
#    1018         if ntree_limit is None:
#    1019             ntree_limit = getattr(self, "best_ntree_limit", 0)
#
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\xgboost\core.py in __init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, enable_categorical)
#     503             feature_names=feature_names,
#     504             feature_types=feature_types,
# --> 505             enable_categorical=enable_categorical)
#     506         assert handle is not None
#     507         self.handle = handle
#
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\xgboost\data.py in dispatch_data_backend(data, missing, threads, feature_names, feature_types, enable_categorical)
#     538     if _is_pandas_df(data):
#     539         return _from_pandas_df(data, enable_categorical, missing, threads,
# --> 540                                feature_names, feature_types)
#     541     if _is_pandas_series(data):
#     542         return _from_pandas_series(data, missing, threads, feature_names,
#
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\xgboost\data.py in _from_pandas_df(data, enable_categorical, missing, nthread, feature_names, feature_types)
#     241                     feature_names, feature_types):
#     242     data, feature_names, feature_types = _transform_pandas_df(
# --> 243         data, enable_categorical, feature_names, feature_types)
#     244     return _from_numpy_array(data, missing, nthread, feature_names,
#     245                              feature_types)
#
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\xgboost\data.py in _transform_pandas_df(data, enable_categorical, feature_names, feature_types, meta, meta_type)
#     205                 categorical type is supplied, DMatrix parameter
#     206                 `enable_categorical` must be set to `True`."""
# --> 207         raise ValueError(msg + ', '.join(bad_fields))
#     208
#     209     if feature_names is None and meta is None:
#
# ValueError: DataFrame.dtypes for data must be int, float, bool or categorical.  When
#                 categorical type is supplied, DMatrix parameter
#                 `enable_categorical` must be set to `True`.city, gender, relevent_experience, major_discipline, company_size, company_type

# %%
# def get_scores(report_df, model, X_test, y_test, name):    
#     report = pd.DataFrame(columns={'ROC-AUC'}, data=[0])
#     report['ROC-AUC'] = roc_auc_score(y_test,model.predict_proba(X_test)[:, 1])
#     report['F1'] = f1_score(y_test, model.predict(X_test))
#     report['precision_0'] = precision_score(
#         y_test, model.predict(X_test), pos_label=0)
#     report['precision_1'] = precision_score(
#         y_test, model.predict(X_test), pos_label=1)
#     report['recall_0'] = recall_score(
#         y_test, model.predict(X_test), pos_label=0)
#     report['recall_1'] = recall_score(
#         y_test, model.predict(X_test), pos_label=1)

#     report.index = [name]
#     report_df = report_df.append(report)
#     return report_df

# %% [markdown]
# ### Polynomial 컬럼 추가(Trial&Error) XGBoost모델 feature_importances_ 기준

# %% [markdown]
# #### 중요도 컬럼뽑기 - 랜덤서치(nopoly,no oversampling) 한번 실행후

# %%
imprt_lst = pd.Series(be.feature_importances_, index=X_train.columns).sort_values(ascending=False)
to_poly_lst = list(imprt_lst[imprt_lst>imprt_lst.quantile(q=0.8)].index)
to_poly_lst
# Out:
# ['city_development_index', 'relevent_experience', 'enrolled_university']

# %%
from sklearn.preprocessing import PolynomialFeatures

poly_f = PolynomialFeatures(degree=2, include_bias=False)
poly_f1 = PolynomialFeatures(degree=2, include_bias=False)

poly_train = poly_f.fit_transform(X.loc[:,X.columns.isin(to_poly_lst)])
poly_test = poly_f1.fit_transform(X_test.loc[:,X_test.columns.isin(to_poly_lst)])

X_train_poly_tomerge = pd.DataFrame(poly_train, columns=poly_f.get_feature_names())
X_test_poly_tomerge = pd.DataFrame(poly_test, columns=poly_f1.get_feature_names())

X_train_poly = pd.concat([X, X_train_poly_tomerge], axis=1)
X_test_poly = pd.concat([X_test, X_test_poly_tomerge], axis=1)

# %%
vars_poly = {f'x{i}':v for i,v in enumerate(to_poly_lst)}
vars_poly
# Out:
# {'x0': 'city_development_index',
#  'x1': 'relevent_experience',
#  'x2': 'enrolled_university'}

# %%
X_train_poly, X_val_poly, y_train_poly, y_val_poly = train_test_split(X_train_poly, y, stratify=y, shuffle=True, random_state=1)
X_train_poly.shape, X_val_poly.shape, y_train_poly.shape, y_val_poly.shape
# Out:
# ((14368, 22), (4790, 22), (14368,), (4790,))

# %%
X_train_poly
# Out:
#        enrollee_id  city  city_development_index  gender  relevent_experience  \
# 12751        18294    83                   0.762       1                    1
# 12061        14050    64                   0.624       1                    0
# 18919          720    49                   0.920       1                    1
# 3215         24912    64                   0.624       1                    1
# 5273          3992    49                   0.920       1                    0
# ...            ...   ...                     ...     ...                  ...
# 1231         15912     5                   0.920       0                    1
# 8701          1740     5                   0.920       1                    0
# 18883        17805    65                   0.899       1                    0
# 17051         9115    50                   0.767       1                    0
# 4200          6042     5                   0.920       1                    0
#
#        enrolled_university  education_level  major_discipline  experience  \
# 12751                  0.0              2.0                 0         2.0
# 12061                  0.0              2.0                 0        12.0
# 18919                  2.0              2.0                 0        13.0
# 3215                   0.0              2.0                 0         5.0
# 5273                   0.0              2.0                 0         4.0
# ...                    ...              ...               ...         ...
# 1231                   0.0              2.0                 1         4.0
# 8701                   0.0              2.0                 0        18.0
# 18883                  0.0              2.0                 0        21.0
# 17051                  0.0              2.0                 0         8.0
# 4200                   0.0              2.0                 1        21.0
#
#        company_size  ...  training_hours     x0   x1   x2      x0^2  x0 x1  \
# 12751           3.0  ...             192  0.762  1.0  0.0  0.580644  0.762
# 12061           4.0  ...               3  0.624  0.0  0.0  0.389376  0.000
# 18919           3.0  ...              52  0.920  1.0  2.0  0.846400  0.920
# 3215            7.0  ...              17  0.624  1.0  0.0  0.389376  0.624
# 5273            2.0  ...             204  0.920  0.0  0.0  0.846400  0.000
# ...             ...  ...             ...    ...  ...  ...       ...    ...
# 1231            0.0  ...             166  0.920  1.0  0.0  0.846400  0.920
# 8701            2.0  ...              26  0.920  0.0  0.0  0.846400  0.000
# 18883           4.0  ...              24  0.899  0.0  0.0  0.808201  0.000
# 17051           0.0  ...             165  0.767  0.0  0.0  0.588289  0.000
# 4200            5.0  ...              83  0.920  0.0  0.0  0.846400  0.000
#
#        x0 x2  x1^2  x1 x2  x2^2
# 12751   0.00   1.0    0.0   0.0
# 12061   0.00   0.0    0.0   0.0
# 18919   1.84   1.0    2.0   4.0
# 3215    0.00   1.0    0.0   0.0
# 5273    0.00   0.0    0.0   0.0
# ...      ...   ...    ...   ...
# 1231    0.00   1.0    0.0   0.0
# 8701    0.00   0.0    0.0   0.0
# 18883   0.00   0.0    0.0   0.0
# 17051   0.00   0.0    0.0   0.0
# 4200    0.00   0.0    0.0   0.0
#
# [14368 rows x 22 columns]

# %% [markdown]
# #### poly-nooversampling

# %%
random_xgb_poly = RandomizedSearchCV(xgb,
                             param_distributions=param,
                             n_iter=10,
                             scoring='accuracy',
                             cv=3,
                             n_jobs=-1,
                             random_state=1
                             )
random_xgb_poly.fit(X_train_poly, y_train_poly)
# Out:
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:01:33] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1, gamma=0,
#                                            gpu_id=-1, importance_type='gain',
#                                            interaction_constraints='',
#                                            learning_rate=0.5, max_delta_step=0,
#                                            max_depth=2, min_child_weight=1,
#                                            missing=nan,
#                                            monotone_constraints='()',
#                                            n_estimators=200, n_jobs=12,
#                                            num_parallel_tree=1, random_state=1,
#                                            reg_alpha=0, reg_lambda=1,
#                                            scale_pos_weight=1, subsample=1,
#                                            tree_method='exact',
#                                            validate_parameters=1,
#                                            verbosity=None),
#                    n_jobs=-1,
#                    param_distributions={'learning_rate': [0.001, 0.005, 0.01,
#                                                           0.05, 0.1, 0.5],
#                                         'max_depth': range(1, 7),
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500]},
#                    random_state=1, scoring='accuracy')

# %%
be_poly = random_xgb_poly.best_estimator_
pd.Series(be_poly.feature_importances_, index=X_train_poly.columns).sort_values(ascending=False)
# Out:
# x1 x2                     0.345908
# city_development_index    0.260006
# relevent_experience       0.183445
# x0 x2                     0.036809
# education_level           0.028735
# enrolled_university       0.023216
# city                      0.021890
# x0 x1                     0.017378
# experience                0.016550
# last_new_job              0.014491
# company_size              0.012117
# enrollee_id               0.010652
# training_hours            0.009614
# company_type              0.008924
# major_discipline          0.007726
# gender                    0.002540
# x0                        0.000000
# x1                        0.000000
# x2                        0.000000
# x0^2                      0.000000
# x1^2                      0.000000
# x2^2                      0.000000
# dtype: float32

# %%
pd.DataFrame(random_xgb_poly.cv_results_).sort_values('rank_test_score')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 2       4.713576      0.022330         0.018083        0.002100
# 9       1.942920      0.012197         0.011390        0.000824
# 4       1.028531      0.007600         0.010266        0.000797
# 6       4.681373      0.012359         0.013348        0.000618
# 7       6.762642      0.058373         0.012206        0.002079
# 5       9.835636      0.044849         0.012548        0.000466
# 8       2.623124      0.012451         0.008796        0.001049
# 1       7.697340      0.063592         0.013519        0.002005
# 0       6.506692      0.069699         0.011230        0.001049
# 3       2.664271      0.013145         0.017255        0.000615
#
#   param_n_estimators param_max_depth param_learning_rate  \
# 2                500               2                0.05
# 9                300               2                 0.1
# 4                100               2               0.005
# 6                500               2                0.01
# 7                500               4               0.001
# 5                500               5               0.005
# 8                100               5                0.05
# 1                300               5                0.05
# 0                200               6                0.05
# 3                200               3                 0.5
#
#                                               params  split0_test_score  \
# 2  {'n_estimators': 500, 'max_depth': 2, 'learnin...           0.789979
# 9  {'n_estimators': 300, 'max_depth': 2, 'learnin...           0.788518
# 4  {'n_estimators': 100, 'max_depth': 2, 'learnin...           0.782881
# 6  {'n_estimators': 500, 'max_depth': 2, 'learnin...           0.783925
# 7  {'n_estimators': 500, 'max_depth': 4, 'learnin...           0.782672
# 5  {'n_estimators': 500, 'max_depth': 5, 'learnin...           0.786221
# 8  {'n_estimators': 100, 'max_depth': 5, 'learnin...           0.785386
# 1  {'n_estimators': 300, 'max_depth': 5, 'learnin...           0.782046
# 0  {'n_estimators': 200, 'max_depth': 6, 'learnin...           0.775783
# 3  {'n_estimators': 200, 'max_depth': 3, 'learnin...           0.771608
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 2           0.783671           0.777615         0.783755        0.005048
# 9           0.782209           0.777198         0.782642        0.004631
# 4           0.780956           0.783880         0.782572        0.001213
# 6           0.781583           0.781165         0.782224        0.001215
# 7           0.779286           0.781583         0.781180        0.001411
# 5           0.779077           0.776989         0.780762        0.003953
# 8           0.781165           0.774692         0.780414        0.004398
# 1           0.775945           0.770933         0.776308        0.004544
# 0           0.776989           0.772395         0.775056        0.001945
# 3           0.767384           0.760702         0.766564        0.004490
#
#    rank_test_score
# 2                1
# 9                2
# 4                3
# 6                4
# 7                5
# 5                6
# 8                7
# 1                8
# 0                9
# 3               10

# %%
pred_train_poly = random_xgb_poly.predict(X_train_poly)
pred_val_poly = random_xgb_poly.predict(X_val_poly)

print('train accuracy :', accuracy_score(y_train_poly, pred_train_poly))
print('validation accuracy :', accuracy_score(y_val_poly, pred_val_poly))
# Out:
# train accuracy : 0.7887667037861915
# validation accuracy : 0.7791231732776618

# %% [markdown]
# ### 오버샘플링

# %%
# from sklearn.decomposition import PCA
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=0)
X_train_ovsp, y_train_ovsp = sm.fit_resample(X_train, list(y_train))

sm_poly = SMOTE(random_state=0)
X_train_poly_ovsp, y_train_poly_ovsp = sm_poly.fit_resample(X_train_poly, list(y_train_poly))

# %% [markdown]
# #### nopoly-oversampling

# %%
random_xgb_ovsp = RandomizedSearchCV(xgb,
                             param_distributions=param,
                             n_iter=10,
                             scoring='accuracy',
                             cv=3,
                             n_jobs=-1,
                             random_state=1
                             )
random_xgb_ovsp.fit(X_train_ovsp, y_train_ovsp)
# Out:
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:02:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1, gamma=0,
#                                            gpu_id=-1, importance_type='gain',
#                                            interaction_constraints='',
#                                            learning_rate=0.5, max_delta_step=0,
#                                            max_depth=2, min_child_weight=1,
#                                            missing=nan,
#                                            monotone_constraints='()',
#                                            n_estimators=200, n_jobs=12,
#                                            num_parallel_tree=1, random_state=1,
#                                            reg_alpha=0, reg_lambda=1,
#                                            scale_pos_weight=1, subsample=1,
#                                            tree_method='exact',
#                                            validate_parameters=1,
#                                            verbosity=None),
#                    n_jobs=-1,
#                    param_distributions={'learning_rate': [0.001, 0.005, 0.01,
#                                                           0.05, 0.1, 0.5],
#                                         'max_depth': range(1, 7),
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500]},
#                    random_state=1, scoring='accuracy')

# %%
be_ovsp = random_xgb_ovsp.best_estimator_
pd.Series(be_ovsp.feature_importances_, index=X_train_ovsp.columns).sort_values(ascending=False)
# Out:
# enrolled_university       0.281953
# city_development_index    0.147921
# education_level           0.140914
# last_new_job              0.117147
# company_type              0.103675
# company_size              0.065948
# city                      0.041969
# gender                    0.027233
# experience                0.022011
# relevent_experience       0.020783
# enrollee_id               0.011491
# training_hours            0.010002
# major_discipline          0.008953
# dtype: float32

# %%
pd.DataFrame(random_xgb_ovsp.cv_results_).sort_values('rank_test_score')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1       9.824725      0.272670         0.014640        0.001380
# 0       8.046455      0.677981         0.014640        0.000797
# 3       3.577685      0.044657         0.013664        0.002391
# 9       2.755569      0.025204         0.010411        0.000460
# 2       6.249968      0.079200         0.013989        0.001218
# 8       3.147269      0.028780         0.010411        0.000920
# 5      11.937436      0.035603         0.021147        0.003680
# 6       5.566443      0.018473         0.014640        0.002391
# 7       8.668167      0.373522         0.015291        0.000460
# 4       1.430163      0.015211         0.011387        0.001217
#
#   param_n_estimators param_max_depth param_learning_rate  \
# 1                300               5                0.05
# 0                200               6                0.05
# 3                200               3                 0.5
# 9                300               2                 0.1
# 2                500               2                0.05
# 8                100               5                0.05
# 5                500               5               0.005
# 6                500               2                0.01
# 7                500               4               0.001
# 4                100               2               0.005
#
#                                               params  split0_test_score  \
# 1  {'n_estimators': 300, 'max_depth': 5, 'learnin...           0.501669
# 0  {'n_estimators': 200, 'max_depth': 6, 'learnin...           0.501808
# 3  {'n_estimators': 200, 'max_depth': 3, 'learnin...           0.502364
# 9  {'n_estimators': 300, 'max_depth': 2, 'learnin...           0.501669
# 2  {'n_estimators': 500, 'max_depth': 2, 'learnin...           0.501947
# 8  {'n_estimators': 100, 'max_depth': 5, 'learnin...           0.507789
# 5  {'n_estimators': 500, 'max_depth': 5, 'learnin...           0.549513
# 6  {'n_estimators': 500, 'max_depth': 2, 'learnin...           0.594159
# 7  {'n_estimators': 500, 'max_depth': 4, 'learnin...           0.625035
# 4  {'n_estimators': 100, 'max_depth': 2, 'learnin...           0.641307
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 1           0.918637           0.930042         0.783449        0.199303
# 0           0.919889           0.927677         0.783125        0.198946
# 3           0.916134           0.924061         0.780853        0.196948
# 9           0.912517           0.926704         0.780297        0.197105
# 2           0.907789           0.923505         0.777747        0.195125
# 8           0.897079           0.914465         0.773111        0.187745
# 5           0.866481           0.889013         0.768336        0.155004
# 6           0.827121           0.845480         0.755586        0.114393
# 7           0.810570           0.827399         0.754335        0.091687
# 4           0.724618           0.733936         0.699954        0.041643
#
#    rank_test_score
# 1                1
# 0                2
# 3                3
# 9                4
# 2                5
# 8                6
# 5                7
# 6                8
# 7                9
# 4               10

# %%
pred_train_ovsp = random_xgb_ovsp.predict(X_train_ovsp)
pred_val_ovsp = random_xgb_ovsp.predict(X_val)

print('train accuracy :', accuracy_score(y_train_ovsp, pred_train_ovsp))
print('validation accuracy :', accuracy_score(y_val, pred_val_ovsp))
# Out:
# train accuracy : 0.8717199814557255
# validation accuracy : 0.4102296450939457

# %% [markdown]
# #### poly-oversampleling

# %%
random_xgb_poly_ovsp = RandomizedSearchCV(xgb,
                             param_distributions=param,
                             n_iter=10,
                             scoring='accuracy',
                             cv=3,
                             n_jobs=-1,
                             random_state=1
                             )
random_xgb_poly_ovsp.fit(X_train_poly_ovsp, y_train_poly_ovsp)
# Out:
# c:\users\inje.jeong\anaconda3\envs\ml\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [21:03:09] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=0.5, booster='gbtree',
#                                            colsample_bylevel=1,
#                                            colsample_bynode=1,
#                                            colsample_bytree=1, gamma=0,
#                                            gpu_id=-1, importance_type='gain',
#                                            interaction_constraints='',
#                                            learning_rate=0.5, max_delta_step=0,
#                                            max_depth=2, min_child_weight=1,
#                                            missing=nan,
#                                            monotone_constraints='()',
#                                            n_estimators=200, n_jobs=12,
#                                            num_parallel_tree=1, random_state=1,
#                                            reg_alpha=0, reg_lambda=1,
#                                            scale_pos_weight=1, subsample=1,
#                                            tree_method='exact',
#                                            validate_parameters=1,
#                                            verbosity=None),
#                    n_jobs=-1,
#                    param_distributions={'learning_rate': [0.001, 0.005, 0.01,
#                                                           0.05, 0.1, 0.5],
#                                         'max_depth': range(1, 7),
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500]},
#                    random_state=1, scoring='accuracy')

# %%
be_poly_ovsp = random_xgb_poly_ovsp.best_estimator_
pd.Series(be_poly_ovsp.feature_importances_, index=X_train_poly_ovsp.columns).sort_values(ascending=False)
# Out:
# relevent_experience       0.310106
# x1                        0.142896
# enrolled_university       0.134845
# city_development_index    0.102941
# education_level           0.071293
# last_new_job              0.042070
# x1 x2                     0.040505
# company_type              0.037511
# company_size              0.027264
# x2^2                      0.020089
# x0^2                      0.017557
# city                      0.014445
# experience                0.007476
# gender                    0.006362
# x0 x2                     0.005338
# enrollee_id               0.005173
# major_discipline          0.004925
# x0 x1                     0.004637
# training_hours            0.004565
# x0                        0.000000
# x2                        0.000000
# x1^2                      0.000000
# dtype: float32

# %%
pd.DataFrame(random_xgb_poly_ovsp.cv_results_).sort_values('rank_test_score')
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 1      12.811375      0.453859         0.018879        0.002040
# 3       4.698781      0.069332         0.015941        0.000460
# 9       3.684741      0.038869         0.012045        0.000598
# 0      10.419325      0.652659         0.018243        0.002343
# 2       8.158308      0.046336         0.016604        0.002619
# 5      16.559726      0.049356         0.022799        0.003445
# 8       4.321545      0.030492         0.013664        0.001594
# 6       7.620798      0.029774         0.019375        0.003931
# 7      12.233893      0.172490         0.018728        0.001214
# 4       1.865458      0.034519         0.011387        0.000460
#
#   param_n_estimators param_max_depth param_learning_rate  \
# 1                300               5                0.05
# 3                200               3                 0.5
# 9                300               2                 0.1
# 0                200               6                0.05
# 2                500               2                0.05
# 5                500               5               0.005
# 8                100               5                0.05
# 6                500               2                0.01
# 7                500               4               0.001
# 4                100               2               0.005
#
#                                               params  split0_test_score  \
# 1  {'n_estimators': 300, 'max_depth': 5, 'learnin...           0.501669
# 3  {'n_estimators': 200, 'max_depth': 3, 'learnin...           0.502225
# 9  {'n_estimators': 300, 'max_depth': 2, 'learnin...           0.501669
# 0  {'n_estimators': 200, 'max_depth': 6, 'learnin...           0.501669
# 2  {'n_estimators': 500, 'max_depth': 2, 'learnin...           0.501669
# 5  {'n_estimators': 500, 'max_depth': 5, 'learnin...           0.539917
# 8  {'n_estimators': 100, 'max_depth': 5, 'learnin...           0.507371
# 6  {'n_estimators': 500, 'max_depth': 2, 'learnin...           0.574548
# 7  {'n_estimators': 500, 'max_depth': 4, 'learnin...           0.623922
# 4  {'n_estimators': 100, 'max_depth': 2, 'learnin...           0.661752
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 1           0.917803           0.928651         0.782707        0.198774
# 3           0.918776           0.924339         0.781780        0.197688
# 9           0.917246           0.925035         0.781317        0.197766
# 0           0.916968           0.924618         0.781085        0.197602
# 2           0.914604           0.922392         0.779555        0.196521
# 5           0.883449           0.897636         0.773667        0.165388
# 8           0.898748           0.910570         0.772230        0.187345
# 6           0.853825           0.863978         0.764117        0.134109
# 7           0.824757           0.842698         0.763792        0.099174
# 4           0.742003           0.744784         0.716180        0.038503
#
#    rank_test_score
# 1                1
# 3                2
# 9                3
# 0                4
# 2                5
# 5                6
# 8                7
# 6                8
# 7                9
# 4               10

# %%
pred_train_poly_ovsp = random_xgb_poly_ovsp.predict(X_train_poly_ovsp)
pred_val_poly_ovsp = random_xgb_poly_ovsp.predict(X_val_poly)

print('train accuracy :', accuracy_score(y_train_poly_ovsp, pred_train_poly_ovsp))
print('validation accuracy :', accuracy_score(y_val, pred_val_poly_ovsp))
# Out:
# train accuracy : 0.8720445062586927
# validation accuracy : 0.7753653444676409
